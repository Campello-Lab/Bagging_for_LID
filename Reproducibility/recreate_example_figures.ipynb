# %%
from Bagging_for_LID.Plotting.Plots.distance_CDF import *
from Bagging_for_LID.run_files.distance_LID_running import *

# %%
save_dir = r'./Output'
save_dir = pathlib.Path(save_dir)
save_dir.mkdir(parents=True, exist_ok=True)

# %%
# 1) Generate data
bs = 200000
X, intrinsic_dims = lollipop_dataset(bs, seed=0, categorical=0.5)

# 2) Fix query point
q = (2, 2)
qx, qy = q

# 3) Choose view box 
extent = (0,4,0,4)

# 4) Choose which probabilities to mark
#quantile_probs = (0.2, 0.6, 1)

# 5) Compute circle radii from the samples (both plots use identical circles)
#circle_ts = distance_quantiles_from_samples(X, q=q, probs=quantile_probs)
circle_ts = (0.2, 0.6, 1, 1.8)

# 6) Subsample points for overlay (optional)
rng = np.random.default_rng(0)
P_plot = X[rng.choice(X.shape[0], size=10000, replace=False)]

# ---- 2D field plot ----
F = empirical_CDF(X, q=q)

fig1, ax1, im1 = plot_distance_cdf_field(
    F,
    q=q,
    extent=extent,
    circle_ts=circle_ts,
    sample_points=P_plot,
    figsize=(19, 10),
    sample_kwargs=dict(s=10, c="green", alpha=0.25, linewidths=0),
    quantile_probs=None,
    grid_res=700,
    cmap_name='Blues',
    save_name='lollipop_cdf_example_heatmap.png',
    colorbar_label=r"$\hat{F}_{\|X-q\|}(t)$",
    save_path=save_dir
)

# ---- CDF curve plot ----
fig2, ax2, ts_used, ps_used = plot_distance_cdf_curve(
    samples=X,
    q=q,
    circle_ts=circle_ts,
    figsize=(10, 10),
    title=" ",
    save_name='lollipop_cdf_example_curve.png',
    marker_fontsize=12,
    save_path=save_dir
)

# %%
#Setup experiment
load=True
directory=r'C:\Users\krp\PycharmProjects\FinalFixLIDGit\pkls'
save_name='ribbon_test_example'
multiprocess=True

#Setup ranges
n = 2500
krange = geom_prog(min=5, max=200, step=50, integer=True, remove_duplicates=True)
trange = [t for t in range(50)]
query = [np.array([[0.5, 0.005]]), np.array([2]), None, np.array([2])]

#Generate experiment results
experiments = generate_all_experiments(n=n, krange=krange, trange=trange, query=query, load=load, directory=directory, save_name=save_name, multiprocess=multiprocess)
exps, experiments_0_k_with_avg_estimates, experiments_t_k = avg_experiments_using_t_as_index(experiments, trange, k_geomprog_large)
exps_trimmed = [experiments_0_k_with_avg_estimates[k] for k in k_geomprog_large[0:len(k_geomprog_large)-8]]

#LID heatmap plot
fig, ax, im, (ks, radii, vals, gt, best_k) = plot_lid_field(
    exps,
    i=n,
    figsize=(18, 10),
    points_kwargs=dict(s=16, c="green", alpha=0.9, linewidths=0),
    cmap_name="RdBu_r",
    save_name="ribbon_LID_example_heatmap.png",
    title = ' ',
    save_path=save_dir
)

#LID curve plot
figC, axC, best_k = plot_lid_curve(
    exps,
    n,
    figsize=(10, 10),
    param="k",
    title=" ",
    save_name='ribbon_LID_example_curve.png',
    n_estimates=len(trange),
    save_path=save_dir
)

plt.show()
# Out:
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_0'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_1'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_2'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_3'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_4'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_5'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_6'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_7'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_8'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_9'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_10'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_11'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_12'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_13'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_14'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_15'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_16'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_17'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_18'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_19'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_20'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_21'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_22'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_23'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_24'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_25'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_26'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_27'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_28'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_29'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_30'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_31'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_32'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_33'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_34'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_35'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_36'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_37'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_38'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_39'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_40'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_41'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_42'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_43'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_44'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_45'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_46'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_47'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_48'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_data_generation'>
# <_io.BufferedReader name='C:\\Users\\krp\\PycharmProjects\\FinalFixLIDGit\\pkls\\ribbon_test_example_t_49'>
